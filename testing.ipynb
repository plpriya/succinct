# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from collections import Counter
from num2words import num2words

import nltk
import os
import string
import numpy as np
import copy
import pandas as pd
import pickle
import re
import math
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# %load_ext autotime
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ppriya\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ppriya\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# %pip install num2words
# Out:
# Requirement already satisfied: num2words in c:\users\ppriya\anaconda3\lib\site-packages (0.5.10)
# Requirement already satisfied: docopt>=0.6.2 in c:\users\ppriya\anaconda3\lib\site-packages (from num2words) (0.6.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
title = "stories"
alpha = 0.3

# %%
print(str(os.getcwd()))
# Out:
# C:\Users\ppriya

# %%
# Out:
# 452 452
# 0 0
# 15 15
# 467
# [('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/100west.txt', 'Going 100 West by 53 North by Jim Prentice (1990)'), ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/13chil.txt', 'The Story of the Sly Fox'), ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/14.lws', 'A Smart Bomb with a Language Parser'), ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/16.lws', 'Two Guys in a Garage, by M. Pshota'), ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/17.lws', 'The Early Days of a High-Tech Start-up are Magic (November 18, 1991) by M. Peshota')]
# [('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/100west.txt',
#   'Going 100 West by 53 North by Jim Prentice (1990)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/13chil.txt',
#   'The Story of the Sly Fox'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/14.lws',
#   'A Smart Bomb with a Language Parser'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/16.lws',
#   'Two Guys in a Garage, by M. Pshota'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/17.lws',
#   'The Early Days of a High-Tech Start-up are Magic (November 18, 1991) by M. Peshota'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/18.lws',
#   'The Couch, the File Cabinet, and the Calendar, by M. Peshota (December 9, 1991)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/19.lws',
#   'Engineering the Future of American Technology by M. Peshota (January 5, 1992)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/20.lws',
#   'What Research and Development Was Always Meant to Be, by M. Peshota'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/3gables.txt',
#   'The Adventure of the Three Gables'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/3lpigs.txt',
#   'The Story of the 3 Little Pigs'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/3sonnets.vrs',
#   'A Collection of Sonnets by Staeorra Rokraven (March 9, 1989)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/3student.txt',
#   'The Adventure of the Three Students'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/3wishes.txt',
#   'The Story of the Three Wishes'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/4moons.txt',
#   'Fiction: The 4 Moons of Death'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/5orange.txt',
#   'The Story of the Five Orange Pips'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/6ablemen.txt',
#   'The Story of the Six Able Men'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/6napolen.txt',
#   'The Adventure of the Six Napoleons'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/7oldsamr.txt',
#   'The Seven Old Samurai'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/7voysinb.txt',
#   'The Seven Voyages of Sinbad the Sailor'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/ab40thv.txt',
#   'The Story of Ali Baba and the 40 Thieves'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/abbey.txt',
#   'The Adventure of the Abbey Grange (RP Story)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/abyss.txt',
#   'How life goes on at the edge of Abyss'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/adler.txt',
#   'The Chronicles of Astrus II: Father Adler by Ben Blumenberg'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/adv_alad.txt',
#   'The Adventures of Aladdin'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/advsayed.txt',
#   "Sayed's Adventures"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/advtthum.txt',
#   'The Adventures of Tom Thumb'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/aesop11.txt',
#   "Aesop's Fables Translated by George Fyler Townsend"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/aesopa10.txt',
#   "Aesop's Fables (84 of Them) from The PaperLess Readers Club"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/aircon.txt',
#   'The Air Conditioning Story'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/aisle.six',
#   'Aisle Six, by Morpheous of LOM'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/aislesix.txt',
#   'Aisle Six, by Morpheous, an LOM Release'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/alad10.txt',
#   'Aladdin and the Wonderful Lamp'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/alissadl.txt',
#   "The Fable of Ali and the Sultan's Saddle"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/altside.hum',
#   'Alternate Side of the Street; Screenplay by Jeff Massie'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/aluminum.hum',
#   'An Aluminum Can A Day, by Carl Mitchell'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/aminegg.txt',
#   'The Fable of Amin and the Eggs'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/angelfur.hum',
#   "Angel's Fur, by Piper Sickles"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/angry_ca.txt',
#   'Cliff-Hanger, a Poem'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/antcrick.txt',
#   'The Fable of the Ant and the Cricket'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/aquith.txt',
#   'My Lord Aquith: Novella by Yves Barbero'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/arcadia.sty',
#   'Arcadia, a Story'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/archive',
#   ' A Collection of Various Good Stories'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/arctic.txt',
#   'The Arctic Circle and Beyond, by Jim Prentice (1990)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/asop',
#   'Updating Aesop, or The Old Lady and the Crypt or Blood'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/assorted.txt',
#   'FICTION: Yahoo! The Ohio VOW has The Bomb by Gregory S. Swann (1986)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/bagel.man',
#   'Bagel Man, by Aldebaran of 11th Hour Productions'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/bagelman.txt',
#   'Bagel-Man, by Aldebaran of 11th Hour Productions'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/batlslau.txt',
#   'Collection of Additional Rules for Battletech, by Matt Murphy'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/beast.asc',
#   'A Collection of Fiction about The Beast'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/beautbst.txt',
#   'The Story of Beauty and the Beast'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/beggars.txt',
#   "The Beggar's Opera, by John Gay, 1728"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/bern',
#   'The Adventures of Bert and Bernece, by  Francis U. Kaltenbaugh'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/berternie.txt',
#   'How Ernie and Bert Came to Be, by 11th Hour Productions'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/bestwish',
#   'FICTION: My Best Wish'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/beyond.hum',
#   'Before the Beyond, by Dallas Vordahl'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/bgb.txt',
#   'Beaver Gone Bad! A mini-manuscript by Pete Stocton and Baron Von Crash'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/bgcspoof.txt',
#   'Mega-Yonkers 2038 : The Story of Knight Foils: Bubble Gum Cards, by Ryan Mathews, January 1992'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/bigred.hum',
#   'Big Red Riding Cape'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/bishop00.txt',
#   'Pyramid Scheme, by Douglas M. Warren, 1993'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/blabnove.hum',
#   'The Super Blab Novel, from Datanet'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/blabnove.txt',
#   'Super Blabnovel-A continuing saga on DATANET'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/blackp.txt',
#   'The Adventure of Black Peter'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/blackrdr',
#   'A Few Words About The Black Rider (German Literature)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/blak',
#   'Lunch in the Park, by Francis U. Kaltenbaugh'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/blasters.fic',
#   'Blasters to the Ready! By William E. Collins'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/blh.txt',
#   "The Birdlover's Holiday, by Andrew P. Varga"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/blind.txt',
#   'Blind Sight, by Lyn Nichols, August 1993'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/blossom.pom',
#   'Little Quaint list of Funny Names to Tell a story.'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/blue',
#   'Soldier Blue, by Rick Arnold'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/bluebrd.txt',
#   'Bluebeard'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/bookem.1',
#   "Boom 'Em Issue #1 (1995)"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/bookem2',
#   "Book 'Em Issue #2 (1995)"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/bookem3',
#   "Book 'Em Issue #3 (1995)"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/brain.damage',
#   'Brain Damage, by Howard I Cannon, 1979'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/bram',
#   'Brambles, by Gordon Chapman'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/bran',
#   'Branded, by John R. Hillman, Jr.'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/breaks1.asc',
#   'Breaks: The Adventures of Richard Nixon in the 21st Century, by Philip H. Farber (1992-1993)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/breaks2.asc',
#   'Breaks: The Adventures of Richard Nixon in the 21st Century, by Philip H. Farber (1992-1993)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/breaks3.asc',
#   'Breaks: The Adventures of Richard Nixon in the 21st Century, by Philip H. Farber (1992-1993)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/bruce-p.txt',
#   'The Adventure of the Bruce-Partington Plans'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/buggy.txt',
#   'Buggy, by Andrew P. Varga (1991)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/buldetal.txt',
#   'Details, a story by The Martyr'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/buldream.txt',
#   'Dreamworld, by Zaphod Beeblebrox'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/bulfelis.txt',
#   'A Story for Cat Lovers'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/bulhuntr.txt',
#   'The Hunter, the Hunted, a story by G. Daniel Flower'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/bulironb.txt',
#   'Story: Iron Man'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/bullove.txt',
#   'Three Paragraphs: Excertps from Something'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/bulmrx.txt',
#   "They Don't Come Any Larger: The Continuing Adventures of Mr. X."),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/bulnland.txt',
#   'A New Land, by Vengeance'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/bulnoopt.txt',
#   'No Options Left, by G. Daniel Flower'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/bulolli1.txt',
#   "The Ill-Fated Voyages of Cap'n Roger, by Julius M. Brown (1989)"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/bulolli2.txt',
#   "The Adventures of Cap'n Roger (Part 2)"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/bulphrek.txt',
#   'A Phreak Encounter (Story)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/bulprint.txt',
#   'Prints of the City, by G. Daniel Flower'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/bulwer.lytton',
#   'It was a dark and stormy night (The Best of the Bulwer-Lytton Contest)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/bulzork1.txt',
#   "The Zorker's Story (Story)"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/bumm',
#   'Bummers by Thomas Nevin Huber'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/bureau.txt',
#   'The Bureau of Procuration (Story)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/burintrv.66',
#   'Interview with William S. Burroughs (1966)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/burintrv.78',
#   'William S. Burroughs: A Sketch (July 1978)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/burintrv.92',
#   'Which is the Fly and Which is the Human? (Interview with William S. Burroughs and David Cronenberg 1992, Equire Magazine'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/burltrs',
#   'The Letters of William S. Burroughs (1945-1959) by Oliver Harris'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/burn',
#   'The Burn: A Synopsis by Michael C. McPherson'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/cabin.txt',
#   'The Cabin, by Adam Poszar (1991)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/cameloto.hum',
#   'Some aborted attempt at a screenplay, maybe'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/campfire.txt',
#   'The Best Campire Story of the Week: Do you have a B.C.?'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/candle.hum',
#   'The Wind, The Cold, The Candle, by Walter Hawn'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/cardcnt.txt',
#   'Accounting for the Cards by H. R. Valimaa'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/ccm.txt',
#   'The Fable of the Cock, the Cat, and the Mouse'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/charlie.txt',
#   'Cosmic Charlie by Colin Campbell'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/chik',
#   'City Chicken, by D. M. Hanna'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/clevdonk.txt',
#   'The Donkey that Thought He Was Clever'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/clon',
#   'Clones to us! By Thomas Nevin Huber'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/cmoutmou.txt',
#   'The Story of The Country Mouse and the Town Mouse'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/comp',
#   "Computers N' Me, by Rich Griebel"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/confilct.fun',
#   'Conflict, by Jason Scott'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/consumdr.hum',
#   'Consumated Dreams, by Melanie Martin Vessels'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/contrad1.hum',
#   'Contradiction 1, by Rick Brunet'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/cooldark.sto',
#   'Cool Darkness: A Cyberpunk Novel by Matthew Carpenter'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/cooldark.txt',
#   'STORY: Cool Darkness, by Matthew Carpenter'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/corcor.hum',
#   'Corcoran, by Bruce Drake'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/cow.exploder',
#   'The Story of the Cow Exploder by CKE Enterprises (1984)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/crabhern.txt',
#   'The Story of the Crab and the Heron'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/crazy.hum',
#   'Crazy Glue, a Novel by Jerry Slaff'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/cum',
#   'Come Into my World by Thomas NEvin Huber'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/curious.george',
#   'Curious Georgie by The Penguin of SubZero AE'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/cybersla.txt',
#   'Book: Revolt of the Cyberslaves, by Lawrence Dworin (1991)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/dakota.txt',
#   'Rifts World Book: North Dakota by Sean Satterlee'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/dan',
#   'Made for Dancing, by Charles Bell'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/darkness.txt',
#   'The Heart of Darkness by Joseph Conrad'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/day.in.mcdonald',
#   'A Day in McDonaldland by G.I. Joe of DETAC (June 10, 1986)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/deal',
#   'Dealer, by Robbie D. Whiting'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/deathmrs.d',
#   'The Death of Ms. D, by William S. Burroughs'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/deer.txt',
#   'The Deer, by Andrew P. Varga (1992)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/descent.poe',
#   'A Descent into the Maelstrom'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/diaryflf.txt',
#   'The Diary of the Swarves'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/dicegame.txt',
#   'Guide to Dice Games of Dungeons and Dragons by Reid Bluebaugh'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/dicksong.txt',
#   'A Manly Wager by Lucillus and a Heaping of Testosterone'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/disco.be.fun',
#   'Disco Can By Fun, by Aldebaran of 11th Hour Productions'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/discocanbefun.txt',
#   'Disco Can Be Fun by Aldebaran of 11th Hour Productions'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/domain.poe',
#   'The Domain of Arnheim'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/dopedenn.txt',
#   'The Story of Dopey Dennis'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/dskool.txt',
#   'Dream School: A Novella'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/dtruck.txt',
#   "Dad's Pickup, by Andrew P. Varga"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/dwar',
#   'Dwarf, by Jeroen Van Drie'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/elite.app',
#   'Fiction: Alex'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/elveshoe.txt',
#   'The Elves and the Shoemaker'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/emperor3.txt',
#   "The Emperor's Three Questions by Leo Tolstoy"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/empnclot.txt',
#   "The Emperor's New Clothes"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/empsjowk.txt',
#   'The Empress Jowka'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/empty.txt',
#   'The Adventure of the Empty House'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/enc',
#   'Encoded in Strands, by Gay Bost'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/encamp01.txt',
#   'Saturday Night at the Shindar Encampment by Lucillus'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/enchdup.hum',
#   'The Enchanted Duplicator, by Walt Willis and Bob Shaw'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/enginer.txt',
#   "The Adventure of the Engineer's Thumb"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/enya_trn.txt',
#   'English Translations of _The Celts_, _Watermark_, and _Shepherd Moons_, by Enya'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/excerpt.hum',
#   'The Snarkout Boys and the Avocado of Death'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/excerpt.txt',
#   'A Relevant Excerpt from "The Snarkout Boys and the Avocado of Death", by Daniel Manus Pinkwater.'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/eyeargon.hum',
#   'The Eye of Argon, by Jim Theis'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/ezoff',
#   'EZ Work, by Gay Bost'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/fable.txt',
#   'The Fable, by Ben Blumenberg'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/fantas.hum',
#   'Pricilla, the Trout Princess, by Gerald E. Gregg'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/fantasy.hum',
#   'The Blab Fantasy Novel'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/fantasy.txt',
#   'The Blab Fantasy novel-Ripped off and edited by The Slipped Disk'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/fea1',
#   'Hula Hoops and Tinker Toys by Nancy VanWormer (1995)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/fea2',
#   'Waterlogged Klingons by L. Shawn Aiken (1994)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/fea3',
#   'Survey Results, by Joe DeRouen (1994)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/fear.hum',
#   'Fear of Growing Old'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/fearmnky',
#   'Fear and the Monkey (A Ouija Board Poem) by William S. Burroughs (1984)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/fgoose.txt',
#   'A List of Father Good Stories'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/fic1',
#   'Beacons of Light, by L. Shawn Aiken (1995)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/fic2',
#   'Experiment, by Ed Davis (1993)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/fic3',
#   'Ouija Warning, by Ed Davis (1993)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/fic4',
#   'A Close Encounter of a Different Kind, by Sylvia L. Ramsey (1993)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/fic5',
#   'The Imp, by Ed Davis (1993)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/fic7',
#   'A Chance Meeting in the Park, by Joe DeRouen'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/fish.txt',
#   'Once There Was a Fish by Doug Rosentrater'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/fleas.txt',
#   'Fleas: A Story, by Adam Poszar (1991)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/flktrp.txt',
#   'Flak Trap (Story) by Brendan Meara (Juanry 18, 1995)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/floc',
#   'Matriarchal Shepherd by Marc Edwards'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/floobs.txt',
#   'The Cube of Shalube...By Dr. Muess (June 24, 1989)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/flute.txt',
#   'The Spirit and the Flute (How Flutes Relate to History)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/flytrunk.txt',
#   'The Story of the Flying Trunk'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/forgotte',
#   'Forgotten Souls by CAC/The Stinker'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/fourth.fic',
#   'Another Fourth of July, by Jeff Epstein'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/fowl.death',
#   'Fowl Death by Nuclear Deth (April 7, 1987)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/foxncrow.txt',
#   'The Story of the Fox and the Crow'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/foxngrap.txt',
#   'The Story of the Fox and the Grapes'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/foxnstrk.txt',
#   'The Story of the Fox and the Stork'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/fran',
#   'Cheese or These? By Francis U. Kaltenbaugh'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/fred.txt',
#   'The Story of Fred.'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/freeman.fil',
#   'The Last Free Man, by Francis W. Porretto'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/friend.s',
#   "Man's Best Friend, by Marty Weiss"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/friends.txt',
#   'Friends: A Story'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/frogp.txt',
#   'The Story of the Frog Prince, by Andrew Varga'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/frum',
#   'The Story of Ronald Frump, by Dave Bealer'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/game.txt',
#   'The Game, by Suki'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/gatherng.txt',
#   'Collection of Poetry by David Fox (1990)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/gay',
#   'A Collection of Poetry by Gay Bost (1994)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/gemdra.txt',
#   'The Story of the Dragons of Gems'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/ghost',
#   'Time for Flowers, by Gay Bost'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/girl',
#   'Dream Girl by Melina Huddy'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/girlclub.txt',
#   'The Girl of the Month Club by Colin Campbell'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/glimpse1.txt',
#   'A Glimpse Into My Mind at 12:45pm, by Sean M. Gomez (1993)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/gloves.txt',
#   'Oops! There was a little messup with the christmas gift!'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/gold3ber.txt',
#   'The Story of Goldilocks and the Three Bears'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/goldbug.poe',
#   'The Gold Bug, by Poe'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/goldenp.txt',
#   'The Adventure of the Golden Pince-Nez'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/goldfish.txt',
#   'The Little Gold Fish'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/goldgoos.txt',
#   'The Tale of the Golden Goose'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/grav',
#   'Memory Cemetery, by Gay Bost'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/graymare.txt',
#   'Nightmare in Grey by Fredric Brown'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/greatlrn.leg',
#   'The Great Learning: The Text of Confucious'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/greedog.txt',
#   'The Parable of the Greedy Dog'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/gulliver.txt',
#   "Gulliver's Travels, by Johnathan Swift (1726)"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/hansgrtl.txt',
#   'The Fable of Hansel and Gretel'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/hareleph.txt',
#   'The Fable of the Hare and the Elephant'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/hareporc.txt',
#   'The Fable of the Hare and the Porcupine'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/haretort.txt',
#   'The Fable of the Hare and the Tortoise'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/healer.txt',
#   'The Soul Healer: A Story by Ben Blumenberg'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/hell4.txt',
#   'Donatien Alphonse Francois de Sade (A Story)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/hellmach.txt',
#   'The Hell Machine, by James C. Lynn (1990)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/helmfuse.txt',
#   'Ashtray and Gherkin (Helmet Fusion Specialists)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/hils',
#   'The Hills of Commerce, by Marilyn Hutchings'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/history5.txt',
#   'The Slopes of Te Aroha'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/hitch2.txt',
#   'Complete Transcription of Douglas Adams\' "Restaurant at the End of the Universe"'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/hitch3.txt',
#   'Complete Transcription of Douglas Adams\' "Life, the Universe and Everything"'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/hole2nar.txt',
#   'The Hole THat Was Too Narrow'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/holmesbk.txt',
#   'The Holmes List: A List of Books That Reference or Discuss Sherlock Holmes'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/home.fil',
#   'The Homecoming, by Francis W. Porretto of Horse Feathers BBS'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/hop-frog.poe',
#   'The Story of Hop Frog'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/horsdonk.txt',
#   'The Horse and the Donkey'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/horswolf.txt',
#   'The Horse and the Wolf'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/hotline1.txt',
#   'Hotline! by James Zachary'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/hotline3.txt',
#   'Hotline! Part III, by James Zachary'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/hotline4.txt',
#   'Hotline! Part IV, by James Zachary'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/hound-b.txt',
#   'The Hound of the Baskervilles, by Sir Arthur Conan Doyle'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/how.ernie.bert',
#   'how Ernie and Bert Came to Be by 11th Hour Productions'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/idi.hum',
#   'The First Adventures of IDI'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/igiv',
#   'I Give Up, by Thomas Nevin Huber'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/imagin.hum',
#   'Just Imagine: A Story'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/immortal',
#   'Immortality by William S. Burroughs'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/immorti.hum',
#   'Immorti, by Todd Rich'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/imonly17.txt',
#   "Please, God, I'm Only 17... by the Elite Executives"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/inter',
#   'Submerged Interface, by Gay Bost'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/island.poe',
#   'The Island of the Fay'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/jackbstl.txt',
#   'The Story of Jack and the Beanstalk'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/jackmac.fic',
#   "Jackmac's Discovery by Jeff Epstein"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/jaynejob.asc',
#   'Be a Clerk All My Life? Not Me!'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/jerichms.hum',
#   'Bricks In The Wall, by M.D. Roccatani'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/jim.asc',
#   'The Book of Jim'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/keeping.insanit',
#   'Keeping Insanity in the Closet, by The Weatherman (April 13th, 1988)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/keepmodu.txt',
#   'Odnaar Keep by David M. Millstein'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/kharian.txt',
#   'The Legends of the Kharianians'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/kneeslapper',
#   'Kneeslapper by Slafathor (July 23, 1991)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/kneeslapper.txt',
#   'Kneeslapper by Slagathor (July 23, 1991)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/knuckle.txt',
#   'The Story of Knucklebones'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/korea.s',
#   'The Furry Orphan of War'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/kzap.txt',
#   "KZAP's Psychedelic Sunday"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/ladylust.hum',
#   "I have no idea where this came from or where it's going."),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/lament.txt',
#   "Offender E477439's Lament"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/lgoldbrd.txt',
#   'The Fable of the Little Golden Bird'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/life.txt',
#   'Notes towards a story'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/lil',
#   'A Letter to Lillian by Gay Bost'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/lionbird',
#   'Lionbirds, by MArtin R. Crim (1994)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/lionmane.txt',
#   "The Adventure of the Lion's Mane"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/lionmosq.txt',
#   'The Fable of the Lion and the Mosquito'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/lionwar.txt',
#   'The Lion Goes to War (Fable)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/lmermaid.txt',
#   'The Fable of the Little Mermaid'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/lmtchgrl.txt',
#   'The Little Matchgirl'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/long1-3.txt',
#   'The Longest Distance by D.W. Boynton (1992)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/lpeargrl.txt',
#   'The Little Pear Girl: A Story'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/lrrhood.txt',
#   'The Story of Little Red Riding Hood'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/ltp',
#   'Liberty Tree Pub: Her Honour, by D. M. Hanna'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/luf',
#   'Luffing, by Ron Fleshman'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/lure.txt',
#   'The Lure of the Temptress (Soft Documentation)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/mario.txt',
#   'MARIO, by Archer Blue: A Short History of Mario'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/mattress.txt',
#   'Once Upon a Mattress, by Nikolai Kingsley, 1995'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/mazarin.txt',
#   'The Adventure of the Mazarin Stone'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/mcdonaldl.txt',
#   'A Day in McDonaldland by G.I. Joe (June 10, 1986)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/melissa.txt',
#   'Melissa and the Green Dragon'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/mike.txt',
#   'An Ode to Mike, by Alien'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/mindprob.txt',
#   'Mind Probe, by Michael Abbot'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/mindwar',
#   'Mind War by William S. Burroughs'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/missing.txt',
#   'The Adventure of the Missing Three-Quarter (A story)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/modemhippy.txt',
#   'Modem Hippy: A Poem by Morpheous of LOM'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/monkking.txt',
#   'The Story of the Monkey King'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/monksol.txt',
#   'The Secret of Monkey Island Unvield by SYNDICATE'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/mouslion.txt',
#   'The Story of the Mouse and the Lion'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/mtinder.txt',
#   'The Story of the Magic Tinderbox'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/musgrave.txt',
#   'The Musgrave Ritual (Story)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/musibrem.txt',
#   'The Musicians of Bremen'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/mydream.txt',
#   'Someone Talks About Some Weird Dreams He Has'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/myeyes',
#   'Poem: Through My Eyes'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/narciss.txt',
#   'The Story of Narcissus'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/nigel.1',
#   'The Saga of Nigel the Hedgehog'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/nigel.10',
#   'The Saga of Nigel the Hedgehog 10 (July 6, 1989)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/nigel.2',
#   'The Saga of Nigel the Hedgehog 2 (May 25, 1989)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/nigel.3',
#   'The Saga of Nigel the Hedgehog 3 (June 2, 1989)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/nigel.4',
#   'The Saga of Nigel the Hedgehog 4 (June 2, 1989)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/nigel.5',
#   'The Saga of Nigel the Hedgehog 5 (June 12, 1989)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/nigel.6',
#   'The Saga of Nigel the Hedgehog 6 (June 12, 1989)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/nigel.7',
#   'The Saga of Nigel the Hedgehog 7 (june 17, 1989)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/nihgel_8.9',
#   'The Saga of Nigel the Hedgehog 8 and 9'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/nitepeek.sto',
#   '"Peek in the Night" by Night Words'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/non2',
#   'Musings by Joe DeRouen (1993)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/non3',
#   'If I Had One Wish... by L.J. Herbert (1993)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/non4',
#   'A Panacea for Cheezy Movies by L. Shawn Aiken'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/obstgoat.txt',
#   'The Tale of the Obstinate Goats'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/omarsheh.txt',
#   'The Fable of Prince Omar and Princess Sheherazade'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/outcast.dos',
#   'The Outcast, by Winwood Reade, 1933'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/oxfrog.txt',
#   'The Fable of the Ox and the Frog'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/paink-ws.txt',
#   'Painkiller, by William Slattery'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/panama.txt',
#   'An Author Argues with his Main Character'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/parotsha.txt',
#   'The Story of the Parrot Shah'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/partya.txt',
#   'What happened on the Friday last October'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/paul_har.sto',
#   "Paul Harvey's List of True Real Stories"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/peace.fun',
#   'Vision of Peace on Earth'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/pepdegener.txt',
#   'Pepsi Degeneration by Morpheous of LOM'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/pepsi.degenerat',
#   'Pepsi Degeneration by Morpheous of LOM'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/perf',
#   'Picture Perfect, by Roberta Belinda'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/pinocch.txt',
#   'The Story of Pinocchio'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/piracy.sto',
#   'Arrr! The Pirates have arrived!'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/plescopm.txt',
#   'Asleep by Craig Plesco'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/poem-1.txt',
#   'Poetry: A Song of Love (October 25, 1993)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/poem-2.txt',
#   'Poetry: Broken Heats, by Kylis Noren (October 19, 1993)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/poem-4.txt',
#   'Poetry: "An Ode to Death" - By Us! (October 19, 1993)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/poplstrm.txt',
#   'The Fable of the Poplar and the Stream'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/pphamlin.txt',
#   'The Pied Piper of Hamelin'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/pregn.txt',
#   'Pregnant Pause by Dorothy Lindman'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/prince.art',
#   'The Princess vs. the Principal, by Marc Perkel'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/progx',
#   'Programmer X, by Greg Borek'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/psf.txt',
#   'The Peasant, the Snake, and the Fox'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/psi',
#   'Psicop, by Jack Hillman'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/psyc',
#   'Psyche and Cupid: A Theory, by Dr. Harold Levdahed'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/pussboot.txt',
#   'The Story of Puss in Boots'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/qcarroll',
#   'How Sailor Ted Got Out of It'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/quarter.c1',
#   'The Plan, by Shannon Carraher (Part 1)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/quarter.c10',
#   'Tea Time with the Devil, by Brant Swancer'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/quarter.c11',
#   'I Spoke with the Sun, by Caroline Kennedy (And Other Poems)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/quarter.c12',
#   'Welcome to the Planet of Kampf, by Jim Zachary'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/quarter.c13',
#   'The Mission, by Jon Lang'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/quarter.c14',
#   'Leftover Stew, by Patrick Barnes'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/quarter.c15',
#   'My Father and Me, by Mike Russello'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/quarter.c16',
#   'Under the Weeping Willow Tree, by Patrick Miner'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/quarter.c17',
#   'Blind Fate, by Toby Bradley'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/quarter.c18',
#   'Bearing Down, by John Dudley'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/quarter.c19',
#   'Hometown Ways, by Amy Slavin'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/quarter.c2',
#   'Remembering, by Kristin Feyen'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/quarter.c3',
#   'The Quarantine, by Moses Domingo'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/quarter.c4',
#   'A Savage Projectile, by Steve Gaines'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/quarter.c5',
#   'Peel Me Away, by Bill DeClercq'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/quarter.c6',
#   'Little White Lines, by Joe Raymundo'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/quarter.c7',
#   'At Midnight, by Karin Johnson'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/quarter.c8',
#   'The Singer in the Depths by Steven Myers'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/quarter.c9',
#   'The Rose, by Suzy Edmonson'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/quest',
#   'The Quest for Axe of the Dwarven Lords by Bruce RW. Reisman'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/quickfix',
#   'Quick Fix, by William S. Burroughs'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/quot',
#   'A Collection of Quotes by Poets about Poetry'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/radar_ra.txt',
#   'Interview with the Radar Ranger: A Work of Fiction by D. Railleur'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/rainda.txt',
#   'Rain Dance (Mechwarrior Fan Fiction) by Douglas M. Warren'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/reality.txt',
#   'The Reality of Our Situation by Kortron'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/reap',
#   'The Reaper, by Gay Bost'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/redragon.txt',
#   'The Fable of the Red Dragon'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/retrib.txt',
#   'Retribution by Andrew Varga (1991)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/rid.txt',
#   'Getting Rid of the Riddler, by Alien'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/robotech',
#   'Book Excerpt: Protoculture and the Children of the Shadow (Robotech)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/rock',
#   'Rock, by D.M. Hanna'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/rocket.sf',
#   'The Space Saga of "Rocket" Roger Robinson (Story)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/roger1.txt',
#   'In Residence by KaRylin'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/running.txt',
#   'Story: Running'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/s&m_plot',
#   "The Plot Thickens: A Writer's Dream, by Cecilio Morales"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/s&m_that',
#   "John's Diner: Who Was The Guy? By Lucia Chambers"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/safe',
#   'Safe Place: A Synopsis, by Michael C. McPherson'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/sanpedr2.txt',
#   'The Fruit of the Gods: Trichoserus Pachanoi'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/shoscomb.txt',
#   'The Adventure of Shoscombe Old Place'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/shrdfarm.txt',
#   "A Shrewd Farmer's Story (Fable)"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/shulk.txt',
#   'The Fable of the Hunter and the Hunted'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/sick-kid.txt',
#   'The Sick Kids: Story by Roger M. Wilcox'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/sight.txt',
#   'Story about Jamie, badly formatted'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/silverb.txt',
#   'Silver Blaze (Story)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/sis',
#   'Sister Mary Agnes by Gay Bost'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/sleprncs.txt',
#   'The Sleeping Princess (Fable)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/snow.txt',
#   'Story about Ed, again badly formatted'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/snowmaid.txt',
#   'The Fable of the Snow Maiden'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/snowqn1.txt',
#   'The Fable of the Snow Queen'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/social.vikings',
#   'Social Vikings by Flat Tire (August 5, 1988)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/socialvikings.txt',
#   'Social Vikings by The Flat Tire (August, 1988)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/solitary.txt',
#   'The Adventure of the Solitary Cyclist'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/space.txt',
#   'Space Travel by Adam Poszar (1990)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/spam.key',
#   'The Key and I, or, My Travels in the Sky, and What I Found There, by Padre Martini, Archdukebishop of West Texas'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/spectacl.poe',
#   'The Spectacles, by Edgar Allen Poe'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/spider.txt',
#   "The World's Fastest Spider, by Andrew Varga (1991)"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/spiders.txt',
#   'Story about Harvey and Spiders'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/sqzply.txt',
#   'Squeeze Play, by Michael A. Stackpole (1989)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/sre-dark.txt',
#   "SRE's Darker Half, by Chris Trendle, Paul Gerth and Robert Chapman"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/stainles.ana',
#   'A Cool 3.7 Million, by The Stainless Steal Rat'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/stairdre.txt',
#   'The Stiarway Dram, by Satinka Istari'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/startrek.txt',
#   'Startrek, The Ultimate Story!'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/stsgreek',
#   "It's All Greek to uncle Thaddeus, by Joe DeRouen (1993)"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/sucker.txt',
#   'The Dark Sucker, by Quantum Mechanic'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/sunday.txt',
#   'Sunday, by Nanci (February 20, 1993)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/superg1',
#   'The Story of SUPERGUY!!'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/szechuan',
#   'The Szechuan Taxi, by Dave Bealer'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/t_zone.jok',
#   'Story: Mission Impossible Meets the Twilight Zone'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/tailbear.txt',
#   'The Tail of the Bear: A Fable'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/tao3.dos',
#   'The Tao Te Ching, translated by James Legge'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/taxnovel.txt',
#   'Back Taxes, a Novel by Paul Mahler (1991-1992)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/tcoa.txt',
#   'The Cask of Amontilado, by Edgar Allan Poe'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/tctac.txt',
#   'The Cockroach that Ate Cincinatti (Poem)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/tearglas.txt',
#   'Tears of Glass by Kimberly Ann Carter (1992)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/telefone.txt',
#   'The Telephone Rape Story'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/terrorbears.txt',
#   'The Terror Bears on the Rampage by Darkside 414'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/testpilo.hum',
#   'Test Pilot, Story by John Vornholt'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/textfile.primer',
#   "The Ramsacker's Textfile Primer by The Ramsacker of Pieces of Eight (July 27, 1989)"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/thanksg',
#   'A Thanksgiving Prayer, by William S. Burroughs'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/the-tree.txt',
#   'The Tree: A Poem'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/thewave',
#   'The Navajo and the Bhuddist (October 19, 1992)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/timem.hac',
#   'The Time Machine, by H.G. Wells (1898)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/times.fic',
#   'Times Doubles Defect; Publisher Possibly Plinked by Jean Blevins'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/timetrav.txt',
#   'The Problem with Time Travel (Story)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/tin',
#   'Tinned Warmth by Gordon Chapman'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/tinsoldr.txt',
#   'The Tin Soldier (Story)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/toilet.s',
#   'My Toilet, my Kingdom, by Bill Luby (1994)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/traitor.txt',
#   'Treason, by Marcus Tullius Cicero'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/tree.txt',
#   'Kevin and the Tree'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/tuc_mees',
#   'The Ed Meese Commission presents Pornography Masquerading as Literature, by Tess Truehard and Gurn Blanston'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/uglyduck.txt',
#   'The Fable of the Ugly Duckling'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/unluckwr.txt',
#   'The Fable of the Unlucky Warrior'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/vaincrow.txt',
#   'The Parable of the Vain Crow'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/vainsong.txt',
#   'A Manly Wager, a Song by Lucillus'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/valen',
#   'Valentine, Story by George Willard'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/vampword.txt',
#   "A Vampyre's Words: Poem"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/vday.hum',
#   "The Valentine's Day Blues, by B.A. Nilsson"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/veiledl.txt',
#   'The Adventure of the Veiled Lodger'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/vgilante.txt',
#   'The Vigilante'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/wall.art',
#   'The Wall, from Karl L. Sandwell-Weiss'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/wanderer.fun',
#   'Poem by David Redish, The Wanderer'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/weaver.txt',
#   'Infromation about Spellweavers'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/weeprncs.txt',
#   'The Weeping Princess'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/whgdsreg.reg',
#   'Introduction to the Neolithic Great Goddess, by Ben Blumenberg (February 12, 1992)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/wisteria.txt',
#   'The Adventure of Wisteria Lodge'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/withdraw.cyb',
#   'My Living Semi-Hell Type Experience Thing, by Urethris, 1992'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/wlgirl.txt',
#   'The Story of the Wise Little Girl'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/wolf7kid.txt',
#   'The Wolf and the Seven Kids'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/wolfcran.txt',
#   'The Wolf and the Crane'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/wolflamb.txt',
#   'The Wolf and the Lamb'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/wombat.und',
#   'The Story of the Wombat, from Floyd Gecko'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/write',
#   'The Three Golden Rules of Poetry by Michael Howard'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/wrt',
#   'The Writer by Thomas Nevin Huber'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/yukon.txt',
#   'The Spell of the Yukon and Other Verses by Robert W. Service'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories/zombies.txt',
#   'Zombies by Suzanne L. McAllister (Spoof/Tribute of George Romero Living Dead Movies)'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories\\SRE/sre01.txt',
#   'SRE: The Saga Of The Best SRE Game Ever Played! By Josh Renaud'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories\\SRE/sre02.txt',
#   'Solar Realms Elite: The True Story of the Unsung Heroes, by Josh Renaud'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories\\SRE/sre03.txt',
#   "Solar Realms Elite: Ultra's Untold Story by Josh Renaud"),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories\\SRE/sre04.txt',
#   'Solar Realms Elite IV: The Confrontation, by Josh Renaud'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories\\SRE/sre05.txt',
#   'Solar Realms Elite V: The Underground, by Josh Renaud'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories\\SRE/sre06.txt',
#   'Solar Realms Elite VI: The Alliance Restored, by Josh Renaud'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories\\SRE/sre07.txt',
#   'Solar Realms Elite 7: Petros, by Josh Renaud'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories\\SRE/sre08.txt',
#   'Solar Realms Elite VIII: Kazik, by Josh Renaud'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories\\SRE/sre09.txt',
#   'Solar Realms Elite IX: Survival of the Fittest, by Josh Renaud'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories\\SRE/sre10.txt',
#   'Solar Realms Elite X: Legacies, by Josh Renaud'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories\\SRE/sre_feqh.txt',
#   'Solar Realms Elite: The Feqh Galaxy, by Josh Renaud'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories\\SRE/sre_finl.txt',
#   'Solar Realms Elite: The Finale by Josh Renaud'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories\\SRE/sre_sei.txt',
#   'Solar Realms Elite: Galaxy Sei, by Josh Renaud'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories\\SRE/sretrade.txt',
#   'The SRE Commerce and Trade Theories, by Josh Renaud'),
#  ('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories\\SRE/srex.txt',
#   'Solar Realms Elite: X1 and X2, by Josh Renaud')]

# %%
def print_doc(id, dataset):
    print(dataset[id])
    file = open(dataset[id][0], 'r', encoding='cp1250')
    text = file.read().strip()
    file.close()
    print(text)

# %%
def convert_lower_case(data):
    return np.char.lower(data)

# %%
def remove_stop_words(data):
    stop_words = stopwords.words('english')
    words = word_tokenize(str(data))
    new_text = ""
    for w in words:
        if w not in stop_words and len(w) > 1:
            new_text = new_text + " " + w
    return new_text

# %%
def remove_punctuation(data):
    symbols = "!\"#$%&()*+-./:;<=>?@[\]^_`{|}~\n"
    for i in range(len(symbols)):
        data = np.char.replace(data, symbols[i], ' ')
        data = np.char.replace(data, "  ", " ")
    data = np.char.replace(data, ',', '')
    return data

# %%
def remove_apostrophe(data):
    return np.char.replace(data, "'", "")

# %%
def stemming(data):
    stemmer= PorterStemmer()
    
    tokens = word_tokenize(str(data))
    new_text = ""
    for w in tokens:
        new_text = new_text + " " + stemmer.stem(w)
    return new_text

# %%
def convert_numbers(data):
    tokens = word_tokenize(str(data))
    new_text = ""
    for w in tokens:
        try:
            w = num2words(int(w))
        except:
            a = 0
        new_text = new_text + " " + w
    new_text = np.char.replace(new_text, "-", " ")
    return new_text

# %%
def preprocess(data):
    data = convert_lower_case(data)
    data = remove_punctuation(data) #remove comma seperately
    data = remove_apostrophe(data)
    data = remove_stop_words(data)
    data = convert_numbers(data)
    data = stemming(data)
    data = remove_punctuation(data)
    data = convert_numbers(data)
    data = stemming(data) #needed again as we need to stem the words
    data = remove_punctuation(data) #needed again as num2word is giving few hypens and commas fourty-one
    data = remove_stop_words(data) #needed again as num2word is giving stop words 101 - one hundred and one
    return data

# %%
def genDataSet():
    dataset = []

    c = False

    folders = [x[0] for x in os.walk('C:\\Users\\ppriya\\OneDrive - NetApp Inc\\Downloads\\stories\\stories')]

    for i in folders:
        file = open(i+"\\index.html", 'r')
        text = file.read().strip()
        file.close()

        file_name = re.findall('><A HREF="(.*)">', text)
        file_title = re.findall('<BR><TD> (.*)\n', text)

        if c == False:
            file_name = file_name[2:]
            c = True

        print(len(file_name), len(file_title))

        for j in range(len(file_name)):
            dataset.append((str(i) +"/"+ str(file_name[j]), file_title[j]))
    return dataset
    
def SetupProcessedData(dataset) :
    processed_text = []
    processed_title = []

    for i in dataset[:N]:
        file = open(i[0], 'r', encoding="utf8", errors='ignore')
        text = file.read().strip()
        file.close()

        processed_text.append(word_tokenize(str(preprocess(text))))
        processed_title.append(word_tokenize(str(preprocess(i[1]))))
    return processed_text, processed_title

# %%
def genDocFreq(processed_text, processed_title) :
    DF = {}

    for i in range(N):
        tokens = processed_text[i]
        for w in tokens:
            try:
                DF[w].add(i)
            except:
                DF[w] = {i}

        tokens = processed_title[i]
        for w in tokens:
            try:
                DF[w].add(i)
            except:
                DF[w] = {i}
    for i in DF:
        DF[i] = len(DF[i])
    return DF

# %%
def doc_freq(DF, word):
    c = 0
    try:
        c = DF[word]
    except:
        pass
    return c

# %%
def calcDFIDF(DF, processed_text, processed_title) :
    doc = 0

    tf_idf = {}

    for i in range(N):

        tokens = processed_text[i]

        counter = Counter(tokens + processed_title[i])
        words_count = len(tokens + processed_title[i])

        for token in np.unique(tokens):

            tf = counter[token]/words_count
            df = doc_freq(DF, token)
            idf = np.log((N+1)/(df+1))

            tf_idf[doc, token] = tf*idf

        doc += 1
    
    doc = 0

    tf_idf_title = {}

    for i in range(N):

        tokens = processed_title[i]
        counter = Counter(tokens + processed_text[i])
        words_count = len(tokens + processed_text[i])

        for token in np.unique(tokens):

            tf = counter[token]/words_count
            df = doc_freq(DF, token)
            idf = np.log((N+1)/(df+1)) #numerator is added 1 to avoid negative values

            tf_idf_title[doc, token] = tf*idf

        doc += 1
    alpha = 0.3
    for i in tf_idf:
        tf_idf[i] *= alpha
    for i in tf_idf_title:
        tf_idf[i] = tf_idf_title[i]
    len(tf_idf)

# %%
dataset = genDataSet()
processed_text, processed_title = SetupProcessedData(dataset)
DF = genDocFreq(processed_text, processed_title)
calcDFIDF(DF, processed_text, processed_title)
# Out:
# 452 452
# 0 0
# 15 15

# %%
def matching_score(tfidf, k, query):
    preprocessed_query = preprocess(query)
    tokens = word_tokenize(str(preprocessed_query))

    print("Matching Score")
    print("\nQuery:", query)
    print("")
    print(tokens)
    
    query_weights = {}

    for key in tf_idf:
        
        if key[1] in tokens:
            try:
                query_weights[key[0]] += tf_idf[key]
            except:
                query_weights[key[0]] = tf_idf[key]
    
    query_weights = sorted(query_weights.items(), key=lambda x: x[1], reverse=True)

    print("")
    
    l = []
    
    for i in query_weights[:10]:
        l.append(i[0])
    
    print(l)
    

#matching_score(10, "Without the drive of Rebeccah's insistence, Kate lost her momentum. She stood next a slatted oak bench, canisters still clutched, surveying")
def cosine_sim(a, b):
    cos_sim = np.dot(a, b)/(np.linalg.norm(a)*np.linalg.norm(b))
    return cos_sim

def fillD(DF) :
    total_vocab_size = len(DF)
    total_vocab_size
    total_vocab = [x for x in DF]
    print(total_vocab[:20])
    D = np.zeros((N, total_vocab_size))
    for i in tf_idf:
        try:
            ind = total_vocab.index(i[1])
            D[i[0]][ind] = tf_idf[i]
        except:
            pass

        def gen_vector(tokens):

    Q = np.zeros((len(total_vocab)))
    
    counter = Counter(tokens)
    words_count = len(tokens)

    query_weights = {}
    
    for token in np.unique(tokens):
        
        tf = counter[token]/words_count
        df = doc_freq(token)
        idf = math.log((N+1)/(df+1))

        try:
            ind = total_vocab.index(token)
            Q[ind] = tf*idf
        except:
            pass
    return Q


def cosine_similarity(k, query):
    print("Cosine Similarity")
    preprocessed_query = preprocess(query)
    tokens = word_tokenize(str(preprocessed_query))
    
    print("\nQuery:", query)
    print("")
    print(tokens)
    
    d_cosines = []
    
    query_vector = gen_vector(tokens)
    
    for d in D:
        d_cosines.append(cosine_sim(query_vector, d))
        
    out = np.array(d_cosines).argsort()[-k:][::-1]
    
    print("")
    
    print(out)

#     for i in out:
#         print(i, dataset[i][0])

Q = cosine_similarity(10, "Without the drive of Rebeccah's insistence, Kate lost her momentum. She stood next a slatted oak bench, canisters still clutched, surveying")


print_doc(200)
